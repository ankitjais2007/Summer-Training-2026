# %%
#Entry and grid layout

import tkinter as tk
root=tk.Tk()
root.title("learn")
root.geometry("700x400")

def getVals():
    tk.Label(root,text=username.get()).grid(column=1)
    tk.Label(root,text=password.get()).grid(column=1)

username=tk.StringVar()
password=tk.StringVar()

tk.Label(root,text="username").grid(row=1,column=1)
tk.Label(root,text="password").grid(row=2,column=1)
tk.Entry(root, textvariable=username).grid(row=1, column=2)
tk.Entry(root, textvariable=password).grid(row=2, column=2)
tk.Button(root, text="submit", command=getVals).grid(row=3, column=2)



root.mainloop()
